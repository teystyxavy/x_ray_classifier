# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.156-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.156-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.156 ultralytics-thop-2.0.14

# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in /usr/local/lib/python3.11/dist-packages (0.10.21)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (3.10.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
# import libraries
import mediapipe as mp
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import numpy as np
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import cv2
import torch
import math
import ultralytics
from ultralytics import YOLO
import shutil
import os
import time

# %%
# global variables
model_path = 'pose_landmarker_full.task'

# %%
# convert input image to mediapipe.Image object
def create_mp_image(image_path):
    mp_image = mp.Image.create_from_file(image_path)
    return mp_image

def draw_landmarks_on_image(rgb_image, detection_result):
    if not detection_result.pose_landmarks:
        return rgb_image

    pose_landmarks_list = detection_result.pose_landmarks
    annotated_image = np.copy(rgb_image)

    # loop through detected poses
    for idx in range(len(pose_landmarks_list)):
        pose_landmarks = pose_landmarks_list[idx]

        # draw landmarks
        pose_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        pose_landmarks_proto.landmark.extend([
            landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in pose_landmarks
        ])

        solutions.drawing_utils.draw_landmarks(
            annotated_image,
            pose_landmarks_proto,
            solutions.pose.POSE_CONNECTIONS,
            solutions.drawing_styles.get_default_pose_landmarks_style()
        )
    return annotated_image

def calc_euclidean_distance(x1, y1, x2, y2):
    '''
        returns the euclidean distance between two points

        Args:
            x1 (float): x coordinate of first point
            y1 (float): y coordinate of first point
            x2 (float): x coordinate of second point
            y2 (float): y coordinate of second point

        Returns:
            float: euclidean distance between the two points
    '''
    return math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

def get_video_properties(cap):
    '''
        returns the video properties

        Args:
            cap (cv2.VideoCapture): video capture object

        Returns:
            tuple: fps, width, height, total_frames
    '''
    original_fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    return original_fps, width, height, total_frames

def add_text_to_frame(display_text, annotated_frame, font=cv2.FONT_HERSHEY_SIMPLEX, font_scale=1.5, thickness=2, bgr=(218, 232, 0)):
    '''
        adds text to a frame

        Args:
            display_text (str): text to be displayed
            font (int): font type
            font_scale (float): font scale
            thickness (int): thickness of the text
            annotated_frame (numpy.ndarray): frame to add text to
            bgr (tuple): background color of the text
    '''
    (text_width, text_height), baseline = cv2.getTextSize(display_text, font, font_scale, thickness)
    line_height = text_height + baseline + 5
    y_offset = 50

    for i, line in enumerate(display_text.split('\n')):
        cv2.putText(annotated_frame, line,
                        org=(10, y_offset + i * line_height),
                        fontFace=font,
                        fontScale=font_scale,
                        color=bgr,
                        thickness=thickness)

def get_classification(pose_detector, det_model, frame, image_path):

  # get mp image
  mp_image = create_mp_image(image_path)

  det_results = det_model(frame, verbose=False)
  pose_result = pose_detector.detect(mp_image)

  light_coordinates = [] # stores tuples of ((x_mid, y_mid, width, height))
  light_detected = False
  l_mid_x, l_mid_y = 0, 0 # midpoint of light bounding box
  annotated_frame = frame
  total_mid_x, total_mid_y = 0, 0

  if det_results and len(det_results) > 0:
    det_result = det_results[0]
    if det_result.boxes is not None and len(det_result.boxes) > 0:
        annotated_frame = det_result.plot() # plot detection results on frame

        # calculate average midpoint of all light detections
        class_indices = det_result.boxes.cls.int().cpu().numpy() if det_result.boxes.cls is not None else []
        for i, class_idx in enumerate(class_indices):
          class_name = det_model.names[class_idx]

          if class_name == 'light':
            light_coordinates.append(det_result.boxes.xyxyn[i].cpu().numpy())
            light_detected = True

  if light_detected:
    for l_x1, l_y1, l_x2, l_y2 in light_coordinates:
      curr_x_mid = (l_x1 + l_x2) / 2
      curr_y_mid = (l_y1 + l_y2) / 2
      total_mid_x += curr_x_mid
      total_mid_y += curr_y_mid
    l_mid_x, l_mid_y = total_mid_x / len(light_coordinates), total_mid_y / len(light_coordinates)

    if pose_result.pose_landmarks is None or len(pose_result.pose_landmarks) == 0:
      display_text = 'light detected but no pose landmarks found'
      class_name = 'unknown'
      return annotated_frame, display_text, class_name

    pose_landmarks = pose_result.pose_landmarks[0]  # Get first detected pose

        # Check if we have enough landmarks (MediaPipe pose has 33 landmarks, indices 0-32)
    if len(pose_landmarks) > 12:  # Need at least landmarks up to index 12
      # get left shoulder, right shoulder, left eye and right eye landmarks
      left_shoulder = pose_landmarks[11]
      right_shoulder = pose_landmarks[12]
      left_eye = pose_landmarks[2]
      right_eye = pose_landmarks[5]

      # check if landmarks are detected
      left_eye_present = False if left_eye.visibility < 0.3 else True
      right_eye_present = False if right_eye.visibility < 0.3 else True
      left_shoulder_present = False if left_shoulder.visibility < 0.3 else True
      right_shoulder_present = False if right_shoulder.visibility < 0.3 else True

      if left_shoulder_present and right_shoulder_present:
        # measure distance between light and shoulders
        left_shoulder_dist = calc_euclidean_distance(l_mid_x, l_mid_y, left_shoulder.x, left_shoulder.y)
        right_shoulder_dist = calc_euclidean_distance(l_mid_x, l_mid_y, right_shoulder.x, right_shoulder.y)

        if left_shoulder_dist < right_shoulder_dist:
          class_name = 'left'
        else:
          class_name = 'right'

        if left_eye_present and right_eye_present:
          class_name += '_AP'
        else:
          class_name += '_outlet'


        display_text = (
          f'Class: {class_name}\n'
          f'Left Shoulder Distance: {left_shoulder_dist:.2f} p\n'
          f'Right Shoulder Distance: {right_shoulder_dist:.2f} p\n'
          f'Left Eye Present: {left_eye_present}\n'
          f'Right Eye Present: {right_eye_present}'
        )

      else:
        display_text = 'Pose detected but no shoulders visible'
        class_name = 'unknown'
    else:
      display_text = 'Pose detected but insufficient landmarks'
      class_name = 'unknown'
  else:
    display_text = 'No light detected'
    class_name = 'unknown'

  return annotated_frame, display_text, class_name
def image_pose_light_classify(pose_model_path, det_model_path, img_path, output_path):
    '''
        real time classification using pose estimation and x-ray light detection. saves images in input_path, and saves to output_path

        Args:
            pose_model_path (str): path to the pose estimation model
            det_model_path (str): path to the x-ray light detection model
            images_path (str): path to the images directory
            output_path (str): path to the output video file
            display_frame (bool): whether to display the frame or not

        Returns:
            None
    '''

    # load models

    base_options = python.BaseOptions(model_asset_path=pose_model_path)
    options = vision.PoseLandmarkerOptions(base_options=base_options, output_segmentation_masks=True)
    pose_model = vision.PoseLandmarker.create_from_options(options)

    det_model = YOLO(det_model_path)

    # load image
    frame = cv2.imread(img_path)

    annotated_frame, display_text, class_name = get_classification(pose_model, det_model, frame, img_path)

    add_text_to_frame(font_scale=0.5, display_text=display_text, annotated_frame=annotated_frame)

    # save image
    cv2.imwrite(output_path, annotated_frame)

    return class_name

def pose_detect_batch_classify(input_dir, output_dir, pose_model_path, det_model_path,
                               classes=['left_AP', 'right_AP', 'left_outlet', "right_outlet"]):
    '''
        classify images in input_dir using pose estimation and x-ray light detection. saves images in output_dir
        and prints the per class accuracy

        Args:
            input_dir (str): path to the input directory
            output_dir (str): path to the output directory
            pose_model_path (str): path to the pose estimation model
            det_model_path (str): path to the x-ray light detection model

        Returns:
            None
    '''
    total_processed = 0
    total_correct = 0
    for class_name in classes:
        curr_input_path = os.path.join(input_dir, class_name)
        curr_output_path = os.path.join(output_dir, class_name)
        shutil.rmtree(curr_output_path, ignore_errors=True)
        os.makedirs(curr_output_path, exist_ok=True)

        print('Processing class:', class_name, 'from', input_dir)

        imgs = [img for img in os.listdir(curr_input_path) if img.endswith('.jpg')]

        total_images = len(imgs)
        correct_classified_count = 0
        processed_count = 0

        print(f'Total images: {total_images}')
        for img in imgs:
            img_path = os.path.join(curr_input_path, img)
            img_output_path = os.path.join(curr_output_path, img)
            predicted_class_name = image_pose_light_classify(pose_model_path=pose_model_path, det_model_path=det_model_path,
                                                img_path=img_path, output_path=img_output_path)

            if predicted_class_name == class_name:
                correct_classified_count += 1

            processed_count += 1

            if processed_count % 30 == 0:
                print(f'Processed {processed_count} of {total_images}')

        print(f'Correctly classified images: {correct_classified_count}')
        print(f'Class accuracy: {correct_classified_count / total_images}')

        total_processed += total_images
        total_correct += correct_classified_count

    print(f'Total processed: {total_processed}')
    print(f'Total correct: {total_correct}')
    print(f'Total Accuracy: {total_correct / total_processed}')

def video_pose_light_classify(pose_model_path, det_model_path, video_path, output_path, display_frame=False):
    '''
        real time classification using pose estimation and light detection

        Args:
            pose_model_path (str): path to the pose estimation model
            det_model_path (str): path to the light detection model
            video_path (str): path to the video file
            output_path (str): path to the output video file
            display_frame (bool): whether to display the frame or not

        Returns:
            None
    '''
    # load models
    base_options = python.BaseOptions(model_asset_path=pose_model_path)
    options = vision.PoseLandmarkerOptions(base_options=base_options, output_segmentation_masks=True)
    pose_model = vision.PoseLandmarker.create_from_options(options)

    det_model = YOLO(det_model_path)

    # open video capture
    cap = cv2.VideoCapture(video_path)

    # get video properties
    original_fps, width, height, total_frames = get_video_properties(cap)

    print(f"Video properties: fps={original_fps}, width={width}, height={height}, total frames={total_frames}")

    # initialize video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video_writer = cv2.VideoWriter(output_path, fourcc, original_fps, (width, height))

    if not video_writer.isOpened():
        print('Error opening video writer')
        cap.release()
        return

    frame_count = 0
    processed_count = 0
    start_time = time.time()

    # process video
    try:
        while cap.isOpened():
            success, frame = cap.read()

            if not success:
                print('Video frame is empty or video processing successfully completed')
                break

            frame_count += 1

            annotated_frame, display_text, class_name = get_classification_v2(pose_model, det_model, frame)

            # add text to frame
            add_text_to_frame(display_text=display_text, annotated_frame=annotated_frame)

            if annotated_frame.shape[:2] != (height, width):
                annotated_frame = cv2.resize(annotated_frame, (width, height))

            video_writer.write(annotated_frame) # save frame to output video
            processed_count += 1

            # print progress
            if frame_count % 30 == 0:
                print(f"Processed {processed_count} frames / {frame_count} total")

            # display frame in real time if requested
            if display_frame:
                final_frame = resize_with_aspect_ratio(annotated_frame, width=500, height=500)

                cv2.imshow('YOLO11 Real-time', final_frame)
                key = cv2.waitKey(1) & 0xFF

                if key == ord('q'):
                    print('Processing stopped by user')
                    break
                elif key == ord('p'):
                    print('Processing paused, press any key to resume')
                    cv2.waitKey(0)
                    print('Processing resumed')

    except Exception as e:
        e.with_traceback(e)
    finally:
        end_time = time.time()
        cap.release()
        video_writer.release()
        cv2.destroyAllWindows()
        print('Video processing completed')
        print(f'Input frames: {frame_count}')
        print(f'Processed frames: {processed_count}')
        print(f'Output saved to: {output_path}')
        print('Inference speed: ', ((end_time - start_time) * 10**3) / frame_count, 'ms/frame')

# %%
image_pose_light_classify(pose_model_path='pose_landmarker_full.task', det_model_path='best.pt', img_path='/content/Left 2_well_2.jpg', output_path='/content/output_img.jpg')
# Out:
# 'left_AP'

# %%
# !unzip /content/input_videos.zip
# Out:
# Archive:  /content/input_videos.zip
#    creating: input_videos/
#   inflating: input_videos/seg_test_vid.mp4
#   inflating: input_videos/test_video.mp4
#   inflating: input_videos/test_video2.mp4
#   inflating: input_videos/test_video3.mp4
#   inflating: input_videos/test_video4.mp4
#   inflating: input_videos/test_video5.mp4

# %%
for input_video in os.listdir('/content/input_videos'):
  input_video_path = os.path.join('/content/input_videos', input_video)
  output_video_path = os.path.join('/content/output_videos', input_video)
  video_pose_light_classify(pose_model_path='/content/pose_landmarker_full.task', det_model_path='/content/best.pt',
                              video_path=input_video_path, output_path=output_video_path)
# Out:
# Video properties: fps=30.0, width=1080, height=1920, total frames=333
# Error opening video writer
# Video properties: fps=0.0, width=0, height=0, total frames=0
# Error opening video writer
# Video properties: fps=30.0, width=1080, height=1920, total frames=337
# Error opening video writer
# Video properties: fps=30.21165555233401, width=1080, height=1920, total frames=521
# Error opening video writer
# Video properties: fps=30.011688030155746, width=1080, height=1920, total frames=1035
# Error opening video writer

# %%
pose_detect_batch_classify(input_dir='/content/test/test', output_dir='/content/mediapipe_pose/test',
                           det_model_path='/content/best.pt', pose_model_path='/content/pose_landmarker_full.task')
# Out:
# Processing class: left_AP from /content/test/test
# Total images: 45
# Processed 30 of 45
# Correctly classified images: 4
# Class accuracy: 0.08888888888888889
# Processing class: right_AP from /content/test/test
# Total images: 30
# Processed 30 of 30
# Correctly classified images: 20
# Class accuracy: 0.6666666666666666
# Processing class: left_outlet from /content/test/test
# Total images: 133
# Processed 30 of 133
# Processed 60 of 133
# Processed 90 of 133
# Processed 120 of 133
# Correctly classified images: 0
# Class accuracy: 0.0
# Processing class: right_outlet from /content/test/test
# Total images: 134
# Processed 30 of 134
# Processed 60 of 134
# Processed 90 of 134
# Processed 120 of 134
# Correctly classified images: 0
# Class accuracy: 0.0
# Total processed: 342
# Total correct: 24
# Total Accuracy: 0.07017543859649122

# %%
# !zip -r /content/mediapipe_pose.zip /content/mediapipe_pose
# Out:
#   adding: content/mediapipe_pose/ (stored 0%)
#   adding: content/mediapipe_pose/test/ (stored 0%)
#   adding: content/mediapipe_pose/test/left_outlet/ (stored 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_12.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_externally_ext_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_internally_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left2_well_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_internally_int_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_well_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left 15_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_externally_ext_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_outlet/Left1_well_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/ (stored 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_4.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_20.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_2.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_22.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_20.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_24.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_30.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_16.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_4.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_26.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_12.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_18.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_28.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_8.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_28.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_18.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_6.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_internally_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_well_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_well_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_int_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_8.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right 15_ext_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_internally_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right2_externally_ext_10.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_externally_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_outlet/Right1_well_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/ (stored 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_28.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_24.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_26.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_18.jpg (deflated 1%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_well_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/left_AP/Left 15_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/ (stored 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_8.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_10.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_16.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_12.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_18.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_14.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_22.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_28.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_26.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_2.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_30.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_24.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_20.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_4.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_int_6.jpg (deflated 0%)
#   adding: content/mediapipe_pose/test/right_AP/Right 15_ext_16.jpg (deflated 0%)
